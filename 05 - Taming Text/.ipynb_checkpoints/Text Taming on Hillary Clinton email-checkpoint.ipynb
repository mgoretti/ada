# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import nltk

from wordcloud import WordCloud

import matplotlib.pyplot as plt


def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

# %% [markdown]
# # Exercise 1
# We will build a world cloud on the email content, for this we will use a Python world cloud library and the nltk library for text processing. We will compare a cloud made without any prior processing with one made with different text processing techniques

# %% [markdown]
# ### Import email data

# %%
df = pd.read_csv('hillary-clinton-emails/Emails.csv', sep=',')
print(df.loc[1]['RawText'])
df.head()
# Out:
# UNCLASSIFIED
# U.S. Department of State
# Case No. F-2015-04841
# Doc No. C05739546
# Date: 05/13/2015
# STATE DEPT. - PRODUCED TO HOUSE SELECT BENGHAZI COMM.
# SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS. NO FOIA WAIVER.
# RELEASE IN
# PART B6
# From:
# Sent:
# To:
# Subject:
# Attachments:
# B6
# Thursday, March 3, 2011 9:45 PM
# H: Latest How Syria is aiding Qaddafi and more... Sid
# hrc memo syria aiding libya 030311.docx; hrc memo syria aiding libya 030311.docx
# CONFIDENTIAL
# March 3, 2011
# For: Hillary
# From: Sid
# Re: Syria aiding Qaddafi
# This memo has two parts. Part one is the report that Syria is providing air support for Qaddafi. Part two is a note
# to Cody from Lord David Owen, former UK foreign secretary on his views of an increasingly complex crisis. It
# seems that the situation is developing into a protracted civil war with various nations backing opposing sides
# ...

# %% [markdown]
# ### We only care about ExtractedBodyText field and the subjects

# %%
#df_extract = df[['ExtractedBodyText']] 
# df_text = df[['ExtractedBodyText']]
# df_subj = df[['ExtractedSubject']]

# concatenate the subject and the text body in the same field
df2 = df.fillna("")
raw_corpus = pd.concat([df2['ExtractedBodyText']  + df2['ExtractedSubject'], df2['SenderPersonId']], axis=1)
raw_corpus.head()
# Out:
#                                                    0 SenderPersonId
# 0                                            FW: Wow             87
# 1  B6\r\nThursday, March 3, 2011 9:45 PM\r\nH: La...
# 2                               ThxRe: Chris Stevens             32
# 3                    FVV: Cairo Condemnation - Final             32
# 4  H <hrod17@clintonemail.com>\r\nFriday, March 1...             80

# %% [markdown]
# ### Concatenate the text of the single emails

# %%
textraw = raw_corpus[0].sum()

# %% [markdown]
# # Pre-processing
# Remove \n

# %%
import string

# %%
print(textraw[0:4000])
# Out:
# FW: WowB6
# Thursday, March 3, 2011 9:45 PM
# H: Latest How Syria is aiding Qaddafi and more... Sid
# hrc memo syria aiding libya 030311.docx; hrc memo syria aiding libya 030311.docx
# March 3, 2011
# For: HillaryThxRe: Chris StevensFVV: Cairo Condemnation - FinalH <hrod17@clintonemail.com>
# Friday, March 11, 2011 1:36 PM
# Huma Abedin
# Fw: H: Latest: How Syria is aiding Qaddafi and more... Sid
# hrc memo syria aiding libya 030311.docx
# Pis print.Pis print.
# -•-...-^
# H < hrod17@clintonernailcom>
# Wednesday, September 12, 2012 2:11 PM
# °Russorv@state.gov'
# Fw: Meet The Right-Wing Extremist Behind Anti-fvluslim Film That Sparked Deadly Riots
# From [meat)
# Sent: Wednesday, September 12, 2012 01:00 PM
# To: 11
# Subject: Meet The Right Wing Extremist Behind Anti-Muslim Film That Sparked Deadly Riots
# htte/maxbiumenthal.com12012/09/meet-the-right-wing-extremist-behind-anti-musiim-tihn-that-sparked-
# deadly-riots/
# Sent from my Verizon Wireless 4G LTE DROID
# ...

# %% [markdown]
# ### Without text preprocessing:

# %%
# Generate a word cloud image
wordcloud = WordCloud().generate(textraw)

#TODO make it prettier/better

# lower max_font_size
wordcloud = WordCloud(width=2000, height=1000).generate(textraw)
plt.figure( figsize=(20,10) )
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Text processing discussion
# First, we can see on the above wordcloud that some mail boilerplate needs to be taken care of. Words like "Re" or "Cc" is useless.
#
# Secondly some words that are not giving any information need to be removed, like "you".

# %%
from nltk.corpus import stopwords
from wordcloud import STOPWORDS

# %%
tokens = nltk.word_tokenize(textraw)

# try stemming
st = nltk.LancasterStemmer()
words_stem = [st.stem(w.lower()) for w in tokens]

words = [w.lower() for w in tokens]

# %%
stopword = set(stopwords.words('english'))

mailword = set(["b6","re", "cc", "date", "subject", "sent", "@", ":", "fw", "originalmessage", "pm", "gov", "doc", "also", "n't", "fyi"])
# for w in mailword:
#     stopword.append(w)


all_stopwords = stopword | mailword | STOPWORDS

# %% [markdown]
# ### Stopword:
# Here we manually remove word using the english nltk.corpus words and then we also use the wordcloud stopword list directly in the WordCloud function call, there is no reason to not directly put eveything in the call to WordCloud it's just for practice.

# %%
from PIL import Image

# %% [markdown]
# # With stemming

# %%
clinton_mask = np.array(Image.open("clinton.jpg"))


wordcloud = WordCloud(width=2000, height=1000,
                       background_color="white", mask = clinton_mask,
                      stopwords = all_stopwords).generate(' '.join(words_stem))

plt.figure( figsize=(20,10) )
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# We clearly see that stemming doesn't make much sense in the context of a word cloud. Maybe using the frequency of the stemmed tokens but then displaying the most frequent word would make more sense.
#
# We decided to just use the simplest approach which is to not use stemming

# %% [markdown]
# # Without Stemming

# %%
clinton_mask = np.array(Image.open("clinton.jpg"))


wordcloud = WordCloud(width=2000, height=1000,
                       background_color="white", mask = clinton_mask,
                      stopwords = all_stopwords).generate(' '.join(words))

plt.figure( figsize=(20,10) )
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# # Pros and Cons:
# We only did basic processing on the corpus but we clearly see that removing stopwords greatly improved the content. For example removing things such as cc and fwd improved the comprehension but since most of the filtering was already done when creating the extractBody column and that the word cloud already removes most stop words we don't see a big difference

# %% [markdown]
# # Exercise 2
#
# Bla bla

# %%
#Get country corpus
import pycountry
from nltk.tokenize import sent_tokenize

#Installed the lib directly because nltk didn't include the sentiment package even though I had the latest version installed
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
text = raw_corpus[0].sum()

# %% [markdown]
# ## Methodology:
# For each email, first we separate each sentence in a DF using nltk sent_tokenize and we add a column for each country
#
# Then for each sentence we use the vaderSentiment package to get the sentiment result and for each mentionned country in that sentence we update add the score
#
# Then we sum over all columns to get overall score

# %%
# get all sentences
all_sentences = sent_tokenize(text)

#Stemming isn't useful to get country names for example:
print(st.stem('Lybian') )
#lyb is not on pycountry
# Out:
# lyb

# %%
len(all_sentences)
# Out:
# 27910

# %%
#build DF out of sentences and countries
#only keep everything before the "," char
countries = [c.name.split(",", 1)[0] for c in pycountry.countries]

df_country = pd.DataFrame(index=countries)
df_country['score'] = 0
df_country['count_'] = 0

# %%
#We will need a list of tokenize and stemmed pycountries:

#for countries that don't have 2 or more words in their name
#first we keep countries that have no ' ' 
countries_single = [c for c in countries if not any(value in c for value in " ")]

country_tokens = nltk.word_tokenize(' '.join(countries_single))
c_stem = [st.stem(w.lower()) for w in country_tokens]
country_stem = [w.lower() for w in c_stem]

# %%
#for important multi name we pick manually
#first we take only first string and change if necessary
countries__multiple = [c.split(' ', 1)[0].replace(",", "") for c in countries if any(value in c for value in " ")]
countries__multiple
# Out:
# ['Åland',
#  'United',
#  'American',
#  'French',
#  'Antigua',
#  'Burkina',
#  'Bosnia',
#  'Saint',
#  'Brunei',
#  'Bouvet',
#  'Central',
#  'Cocos',
#  'Côte',
#  'Cook',
#  'Cabo',
#  'Costa',
#  'Christmas',
#  'Cayman',
#  'Dominican',
#  'Western',
#  'Falkland',
#  'Faroe',
#  'United',
#  'Equatorial',
#  'French',
#  'Hong',
#  'Heard',
#  'Isle',
#  'British',
#  'Saint',
#  'Lao',
#  'Saint',
#  'Sri',
#  'Saint',
#  'Marshall',
#  'Northern',
#  'New',
#  'Norfolk',
#  'New',
#  'Papua',
#  'Puerto',
#  'French',
#  'Russian',
#  'Saudi',
#  'South',
#  'Saint',
#  'Svalbard',
#  'Solomon',
#  'Sierra',
#  'El',
#  'San',
#  'Saint',
#  'South',
#  'Sao',
#  'Sint',
#  'Syrian',
#  'Turks',
#  'Trinidad',
#  'United',
#  'United',
#  'Holy',
#  'Saint',
#  'Virgin',
#  'Virgin',
#  'Viet',
#  'Wallis',
#  'South']

# %%
country_single_stemmed_df = pd.DataFrame(index=countries_single)
country_single_stemmed_df["stemmed"] = country_stem
country_single_stemmed_df.head(5)
# Out:
#              stemmed
# Aruba           arub
# Afghanistan     afgh
# Angola         angol
# Anguilla     anguill
# Albania        alban

# %%
analyzer = SentimentIntensityAnalyzer()
analyzer.polarity_scores("Where is Brian?")

#runs for a long time
for sentence in all_sentences:
    score = analyzer.polarity_scores(sentence)
    
    #find country mentionned in text
    #Exact matching
    countries_sent = {c for c in countries if c in sentence}
    
    #tokenize and stem all word of the sentence and use stemmed country names
    
    sent_tokens = nltk.word_tokenize(sentence.lower())
    words_stem = [st.stem(w) for w in sent_tokens]
    words = [w.lower() for w in words_stem]
    
    countries_sent2 = {c[0] for c in country_single_stemmed_df.iterrows() if c[1][0] == (w for w in words) }
    
    #check with alpha1 and 2
    #Actually using it is problematic and would require some manual crafting for example andorre gives and
    #countries_sent3 = {c.name.split(",", 1)[0] for c in pycountry.countries if c.alpha_2 in sentence }
    #countries_sent4 = {c.name.split(",", 1)[0] for c in pycountry.countries if c.alpha_3.lower() in sent_tokens }
    
    # countries_sent2 | 
    for c in countries_sent | countries_sent2:
        new_score = df_country.xs(c)['score'] + score.get("compound")
        new_count = df_country.xs(c)['count_'] + 1
        df_country.set_value(c, ["score", "count_"], [new_score, new_count])

# %%
df_country['score'] = df_country['score'] / df_country['count_'] #should be normalized?
sent = df_country.sort_values(by='count_', ascending=False).head(30)

# %%
df_country.sort_values(by='count_', ascending=False)
# Out:
#                                       score    count_
# Israel                             0.094242  840.0000
# Iran                               0.042093  425.0000
# United States                      0.410599  414.0000
# Afghanistan                        0.058453  391.0000
# Haiti                              0.218923  363.0000
# China                              0.109961  331.0000
# Pakistan                           0.090902  323.0000
# Libya                             -0.040600  256.0000
# Iraq                              -0.010998  228.0000
# India                              0.148152  180.0000
# Korea                              0.493348  128.0000
# Ireland                            0.235946  106.0000
# Egypt                              0.057607   84.0000
# Palau                              0.327573   77.0000
# Brazil                             0.184408   76.0000
# Mexico                             0.162328   74.0000
# ...

# %% [markdown]
# # Plot

# %%
def showbarfreq(x):

    # Credits to Stack Overflow :
    # http://stackoverflow.com/questions/31313606/pyplot-matplotlib-bar-chart-with-fill-color-depending-on-value
    from matplotlib import cm

    plt.figure( figsize=(20,10) )

    # Set up colors : red to green
    y = np.array(x['score'])
    colors = cm.RdYlGn(y / float(max(y)))
    plot = plt.scatter(y, y, c=y, cmap = 'RdYlGn')
    plt.clf()
    clb = plt.colorbar(plot)
    clb.ax.set_title("Sentiment")

    # Display bar plot : country frequency vs. country name, with color indicating polarity score
    plt.bar(range(x.shape[0]), x['count_'], align='center', tick_label=x.index, color=colors)
    plt.xticks(rotation=45, ha='right')
    plt.xlabel("Country")
    plt.ylabel("Frequency")
    plt.show()
    
showbarfreq(sent)

# %% [markdown]
# # Sentiment analysis on emails instead of sentences

# %%
df_country2 = pd.DataFrame(index=countries)
df_country2['score'] = 0
df_country2['count_'] = 0

for email in raw_corpus.iterrows():
    mail = email[1][0]
    
    score = analyzer.polarity_scores(mail)
    
    #find country mentionned in text
    #Exact matching
    countries_sent = {c for c in countries if c in mail}
    
    #tokenize and stem all word of the sentence and use stemmed country names
    sent_tokens = nltk.word_tokenize(mail.lower())
    words_stem = [st.stem(w) for w in sent_tokens]
    words = [w.lower() for w in words_stem]
    
    countries_sent2 = {c[0] for c in country_single_stemmed_df.iterrows() if c[1][0] == (w for w in words) }
    
    #check with alpha1 and 2
    #it is problematic and would require some manual crafting for example andorre alpha_3 is "and"
    #countries_sent3 = {c.name.split(",", 1)[0] for c in pycountry.countries if c.alpha_2 in sentence }
    #countries_sent4 = {c.name.split(",", 1)[0] for c in pycountry.countries if c.alpha_3.lower() in sent_tokens }
    
    # countries_sent2 | 
    for c in countries_sent | countries_sent2:
        new_score = df_country2.xs(c)['score'] + score.get("compound")
        new_count = df_country2.xs(c)['count_'] + 1
        df_country2.set_value(c, ["score", "count_"], [new_score, new_count])
       
    
    
df_country2['score'] = df_country2['score'] / df_country2['count_'] #should be normalized?
sent2 = df_country2.sort_values(by='count_', ascending=False).head(30)    
    
showbarfreq(sent2)

# %%
st.stem("Guinea")
# Out:
# 'guine'

# %% [markdown]
# # Exercise 3

# %%
from gensim import models, corpora

# %% [markdown]
# We split the documents by senderId (we could do better by trying to reconstruct email chains but it's too much of a hassle)

# %%
grouped_mails = raw_corpus.groupby('SenderPersonId').sum()
final_mails = grouped_mails[grouped_mails[0] != ""][0]

# %% [markdown]
# generate the documents

# %%
docs = [text.lower() for text in final_mails]

# %% [markdown]
# tokenize the docs

# %%
def tokenize(doc):
    tokens = nltk.word_tokenize(doc)
    
    # remove stopwords and punctuation (which is always short)
    cleaned_tokens = [token for token in tokens if token not in all_stopwords and len(token) > 2]
    
    # maybe stem?
    
    return cleaned_tokens

tokenized_docs = [tokenize(doc) for doc in docs]

# %% [markdown]
# Build the corpus and run the LDA model:

# %% [markdown]
# # 10 topics

# %%
dictionary = corpora.Dictionary(tokenized_docs)
corpus = [dictionary.doc2bow(text) for text in tokenized_docs]

lda = models.ldamodel.LdaModel(corpus, num_topics=10, id2word = dictionary)
lda.print_topics()
# Out:
# [(0,
#   '0.004*"said" + 0.004*"call" + 0.004*"state" + 0.004*"one" + 0.003*"obama" + 0.003*"president" + 0.003*"u.s." + 0.003*"secretary" + 0.003*"new" + 0.002*"2009"'),
#  (1,
#   '0.006*"state" + 0.004*"said" + 0.004*"obama" + 0.003*"secretary" + 0.003*"new" + 0.003*"u.s." + 0.003*"house" + 0.003*"one" + 0.003*"people" + 0.003*"time"'),
#  (2,
#   '0.006*"office" + 0.005*"secretary" + 0.005*"state" + 0.003*"one" + 0.003*"department" + 0.003*"president" + 0.003*"obama" + 0.003*"new" + 0.003*"said" + 0.003*"meeting"'),
#  (3,
#   '0.006*"secretary" + 0.004*"state" + 0.004*"call" + 0.004*"new" + 0.004*"office" + 0.003*"president" + 0.003*"said" + 0.003*"obama" + 0.003*"time" + 0.003*"one"'),
#  (4,
#   '0.004*"obama" + 0.003*"state" + 0.003*"call" + 0.003*"said" + 0.003*"new" + 0.003*"one" + 0.003*"u.s." + 0.003*"2010" + 0.003*"time" + 0.002*"president"'),
#  (5,
# ...

# %% [markdown]
# # 20 topics

# %%
dictionary = corpora.Dictionary(tokenized_docs)
corpus = [dictionary.doc2bow(text) for text in tokenized_docs]

lda = models.ldamodel.LdaModel(corpus, num_topics=25, id2word = dictionary)
lda.print_topics()
# Out:
# [(14,
#   '0.005*"state" + 0.004*"secretary" + 0.004*"office" + 0.004*"obama" + 0.004*"new" + 0.003*"department" + 0.003*"said" + 0.003*"time" + 0.003*"one" + 0.003*"u.s."'),
#  (3,
#   '0.003*"one" + 0.003*"state" + 0.003*"u.s." + 0.003*"new" + 0.003*"2010" + 0.003*"said" + 0.003*"obama" + 0.003*"time" + 0.003*"call" + 0.003*"people"'),
#  (18,
#   '0.004*"said" + 0.004*"state" + 0.004*"obama" + 0.003*"call" + 0.003*"office" + 0.003*"one" + 0.003*"new" + 0.003*"secretary" + 0.003*"u.s." + 0.003*"president"'),
#  (5,
#   '0.005*"state" + 0.004*"new" + 0.003*"office" + 0.003*"obama" + 0.003*"2010" + 0.003*"u.s." + 0.003*"clinton" + 0.003*"president" + 0.003*"said" + 0.003*"2009"'),
#  (6,
#   '0.005*"call" + 0.005*"secretary" + 0.004*"one" + 0.004*"state" + 0.003*"office" + 0.003*"said" + 0.003*"president" + 0.003*"time" + 0.003*"obama" + 0.003*"see"'),
#  (7,
# ...

# %% [markdown]
# # Conclusion
#
# All topics are very similar (mention stuff like obama, president, secretary and u.s.)
