# %% [markdown]
# # imports

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from dateutil.relativedelta import relativedelta


import seaborn as sns

from functools import reduce

from sklearn.cross_validation import train_test_split

from sklearn import ensemble

# %%
# import df
df = pd.read_csv('CrowdstormingDataJuly1st.csv', parse_dates = ['birthday'])
df.head()
# Out:
#      playerShort         player             club leagueCountry   birthday  \
# 0  lucas-wilchez  Lucas Wilchez    Real Zaragoza         Spain 1983-08-31
# 1     john-utaka     John Utaka  Montpellier HSC        France 1982-08-01
# 2    abdon-prats    Abdón Prats     RCD Mallorca         Spain 1992-12-17
# 3     pablo-mari     Pablo Marí     RCD Mallorca         Spain 1993-08-31
# 4     ruben-pena     Rubén Peña  Real Valladolid         Spain 1991-07-18
#
#    height  weight              position  games  victories    ...     rater2  \
# 0   177.0    72.0  Attacking Midfielder      1          0    ...       0.50
# 1   179.0    82.0          Right Winger      1          0    ...       0.75
# 2   181.0    79.0                   NaN      1          0    ...        NaN
# 3   191.0    87.0           Center Back      1          1    ...        NaN
# 4   172.0    70.0      Right Midfielder      1          1    ...        NaN
#
#    refNum  refCountry  Alpha_3   meanIAT    nIAT     seIAT   meanExp    nExp  \
# 0       1           1      GRC  0.326391   712.0  0.000564  0.396000   750.0
# 1       2           2      ZMB  0.203375    40.0  0.010875 -0.204082    49.0
# 2       3           3      ESP  0.369894  1785.0  0.000229  0.588297  1897.0
# 3       3           3      ESP  0.369894  1785.0  0.000229  0.588297  1897.0
# 4       3           3      ESP  0.369894  1785.0  0.000229  0.588297  1897.0
#
#       seExp
# 0  0.002696
# 1  0.061504
# 2  0.001002
# 3  0.001002
# 4  0.001002
#
# [5 rows x 28 columns]

# %% [markdown]
# # Cleaning

# %%
# We first drop players that don't have a skin rating (caused by the absence of photos)
print ('we drop ' + str(round(100*df[df.photoID.isnull()].count()[1]/ df.count()[1], 2)) + '% of observation because they don\'t have a picture')

df = df[df.photoID.notnull()]
print(reduce(lambda x,y: x or y, df['rater1'].isnull()))
print(reduce(lambda x,y: x or y, df['rater2'].isnull())) # all ratings exist
# Out:
# we drop 0.0% of observation because they don't have a picture
# False
# False

# %%
# abs(df['rater1'] - df['rater2'])
c = sns.color_palette()
jitter_x = np.random.normal(0, 0.04, size=len(df.rater1))
jitter_y = np.random.normal(0, 0.04, size=len(df.rater2))
sns.jointplot(df.rater1 + jitter_x, df.rater2 + jitter_y, kind='kde')
# Out:
# /Users/Marco/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# As can be observed in the jointplot above, the only real difference in rating is between the 2 lightests colors). Since we cannot determine the skin color of a player where the 2 raters are different, we drop those observations.

# %%
# drop all players (so rows) that don't have the same skin color rating
print ('we drop ' + str(round(100*df[df['rater1'] != df['rater2']].count()[1] / df.count()[1], 2)) + '% of observation because they don\'t have the same rating')
df = df[df['rater1'] == df['rater2']]
# Out:
# we drop 0.0% of observation because they don't have the same rating

# %%
df.apply(lambda x: x.isnull(), axis=0).sum()
# Out:
# playerShort        0
# player             0
# club               0
# leagueCountry      0
# birthday           0
# height             0
# weight             0
# position           0
# games              0
# victories          0
# ties               0
# defeats            0
# goals              0
# yellowCards        0
# yellowReds         0
# redCards           0
# photoID            0
# rater1             0
# rater2             0
# refNum             0
# refCountry         0
# Alpha_3            1
# meanIAT          110
# nIAT             110
# seIAT            110
# meanExp          110
# nExp             110
# seExp            110
# dtype: int64

# %% [markdown]
# We see that there are a few missing values. We can simply drop the players that don't have an height or weight (not many).
# Since there are a lot of players without a position we create a category for them.

# %%
# drop players without reported height
df = df[df['height'].notnull()]
# drop players without reported weight
df = df[df['weight'].notnull()]

# create a noPosition category for players without a position
df.loc[df['position'].isnull(), 'position'] = 'noPosition'

# %%
df.groupby('playerShort').agg(lambda x: len(set(x)) == 1).apply(lambda col: reduce(lambda x, y: x and y, col), axis=0)
# Out:
# player            True
# club              True
# leagueCountry     True
# birthday          True
# height               1
# weight               1
# position          True
# games            False
# victories        False
# ties             False
# defeats          False
# goals            False
# yellowCards      False
# yellowReds       False
# redCards         False
# photoID           True
# rater1               1
# rater2               1
# refNum           False
# refCountry       False
# Alpha_3          False
# meanIAT              0
# nIAT                 0
# seIAT                0
# meanExp              0
# nExp                 0
# seExp                0
# dtype: object

# %% [markdown]
# As we can see, the club, league country and position stay constant so we can aggregate them.
#
# We just check if it's also correct for height and weight:

# %%
df[['playerShort', 'height', 'weight']].groupby('playerShort').agg(lambda x: len(set(x)) == 1).mean()
# Out:
# height    1.0
# weight    1.0
# dtype: float64

# %% [markdown]
# # Feature generation

# %% [markdown]
# We aggregate the information on the player level (making the assumption that there is always only one referee so that games are not duplicated in the aggregation)

# %%
print(df.keys())
print(df.position.value_counts())
df.groupby('playerShort').sum()
# Out:
# Index(['playerShort', 'player', 'club', 'leagueCountry', 'birthday', 'height',
#        'weight', 'position', 'games', 'victories', 'ties', 'defeats', 'goals',
#        'yellowCards', 'yellowReds', 'redCards', 'photoID', 'rater1', 'rater2',
#        'refNum', 'refCountry', 'Alpha_3', 'meanIAT', 'nIAT', 'seIAT',
#        'meanExp', 'nExp', 'seExp'],
#       dtype='object')
# Center Back             16393
# Center Forward          12860
# Defensive Midfielder    10834
# Goalkeeper               8111
# Attacking Midfielder     7722
# Left Fullback            6670
# noPosition               6542
# Right Fullback           6352
# Left Midfielder          4318
# Center Midfielder        4031
# Right Midfielder         3954
# Left Winger              3866
# Right Winger             3360
# Name: position, dtype: int64
#                          height   weight  games  victories  ties  defeats  \
# playerShort
# aaron-lennon            16665.0   6363.0    412        200    97      115
# aaron-ramsey            18512.0   7904.0    260        150    42       68
# abdelhamid-el-kaoutari   6660.0   2701.0    124         41    40       43
# abdou-traore_2           7560.0   3108.0     97         41    23       33
# abdoulwhaid-sissoko     10080.0   3808.0    121         34    25       62
# abdul-razak              5940.0   2574.0     36         16     8       12
# abelaziz-barrada         7215.0   3042.0     85         28    25       32
# abou-diaby              12220.0   4875.0    208        109    51       48
# yoan-gouffran           0.030122   31.133627    962091.0  0.166428
# yohan-cabaye            0.060782   52.822041   1381927.0  0.320160
# yohandry-orozco         0.102211   30.217246   2100002.0  0.597494
# yossi-benayoun          0.105641   76.875994   4335072.0  0.665192
# younes-belhanda         0.182880   34.632221    157985.0  0.908687
# younes-kaboul           0.034445   38.672450   1338000.0  0.188349
# zdravko-kuzmanovic      0.094370   68.107131    851738.0  0.527629
# ze-castro               0.013846   34.205958    181892.0  0.061664
# zhi-gin-lam             0.004472   27.549285    653868.0  0.018455
# zlatan-alomerovic       0.003709   22.845749    542232.0  0.015304
# zlatan-ibrahimovic      0.067651   92.085484   1077841.0  0.324615
# zoltan-gera             0.052737   66.719162   3059538.0  0.257482
# zoltan-stieber          0.006141   19.101036    433229.0  0.026941
# zubikarai               0.006508   17.165149     58328.0  0.028437
# zurutuza                0.014294   23.628702     75401.0  0.064680
#
# [1187 rows x 20 columns]

# %%
def genFeatures(player):
    sample = player.iloc(0)[0] # used to get general infos
    
    age = relativedelta(datetime.datetime.now(), sample['birthday']).years
    
    bmi = sample['weight'] / pow(sample['height']/100, 2)
    games = player['games'].sum()
    winRate = player['victories'].sum() / games
    yellowRedsRate = player['yellowReds'].sum() / games
    yellowRate = player['yellowCards'].sum() / games
    redRate = player['redCards'].sum() / games
    
    
    
    # TODO something about yellow / red rate with racially biased refs vs non-biased
    
    goalRatio = player['goals'].sum() / games
    # TODO some feature with the goal ratio AND offensive position
    
    return pd.Series({
            'player': sample['player'], # constant
            'club': sample['club'],
            'leagueCountry': sample['leagueCountry'],
            'age': age,
            'height': sample['height'],
            'weight': sample['weight'], 
            'bmi': bmi,
            'games': games,
            'winRate': winRate,
            'yellowRate': yellowRate,
            'yellowRedsRate': yellowRedsRate,
            'yellowOverRed': redRate/(yellowRate+1),
            'redRate': redRate,
            'skinColor': sample['rater1'], # we only keep players where rater1 == rater2
            'goalRatio': goalRatio
            })

players = df.groupby('playerShort').apply(genFeatures)
players
# Out:
#                         age        bmi                  club  games  \
# playerShort
# aaron-lennon             29  23.140496     Tottenham Hotspur    412
# aaron-ramsey             25  23.986870            Arsenal FC    260
# abdelhamid-el-kaoutari   26  22.530864       Montpellier HSC    124
# abdou-traore_2           28  22.839506    Girondins Bordeaux     97
# abdoulwhaid-sissoko      26  20.987654           Stade Brest    121
# abdul-razak              24  24.074074       Manchester City     36
# abelaziz-barrada         27  22.790358             Getafe CF     85
# abou-diaby               30  21.220009            Arsenal FC    208
# adam-bodzek              31  23.334121    Fortuna Düsseldorf    211
# adam-federici            31  25.464011            Reading FC    206
# adam-hlousek             27  21.502943        1. FC Nürnberg    131
# adam-johnson             29  20.244898        Sunderland AFC    339
# adam-pinter              27  21.052632         Real Zaragoza     82
# adam-smith_3             25  24.391059           Millwall FC    131
# adam-szalai              29  23.356332       1. FSV Mainz 05    182
# adan                     29  24.376731           Real Madrid     44
# adel-taarabt             27  24.074074   Queens Park Rangers    209
# younes-kaboul           0.436508       0.007220    0.099206        0.015873
# zdravko-kuzmanovic      0.460177       0.002625    0.123894        0.002950
# ze-castro               0.455621       0.005076    0.165680        0.005917
# zhi-gin-lam             0.417323       0.000000    0.062992        0.000000
# zlatan-alomerovic       0.450450       0.008264    0.090090        0.000000
# zlatan-ibrahimovic      0.621087       0.008559    0.154860        0.006590
# zoltan-gera             0.382653       0.002294    0.112245        0.002551
# zoltan-stieber          0.338028       0.000000    0.084507        0.000000
# zubikarai               0.297872       0.040816    0.042553        0.000000
# zurutuza                0.425000       0.000000    0.137500        0.000000
#
# [1187 rows x 15 columns]

# %%
y = players['skinColor']
features = ['games', 'goalRatio', 'age', 'bmi', 'height', 'weight', 'yellowRate', 'yellowRedsRate', 'redRate', 'yellowOverRed', 'winRate']
X = players[features]

# %%
# generate the final test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=4)

# %%
y_train
# Out:
# playerShort
# slobodan-medojevic           0.25
# edu-oriol                    0.00
# jonathan-brison              0.25
# alberto-perea                0.25
# kevin-theophile-catherine    0.75
# michael-essien               1.00
# cedric-carrasso              0.25
# philippe-senderos            0.00
# bernd-nehrig                 0.00
# rio-mavuba                   0.75
# emre-beloezoglu              0.25
# guaita                       0.25
# toni_12                      0.25
# christian-traesch            0.25
# mohamed-amsif                0.50
# torsten-oehrl                0.00
# andre-luiz_3                 0.75
# daniel-wass                  0.00
# sylvio-rodelin               0.50
# ibrahim-afellay              0.50
# constant-djakpa              1.00
# ragnar-klavan                0.00
# leighton-baines              0.25
# geoffrey-dernis              0.25
# sebastian-tyrala             0.00
# kevin-nolan                  0.25
# gueida-fofana                1.00
# raul_10                      0.00
# kolja-pusch                  0.00
# nikolce-noveski              0.25
#                              ...
# gervinho                     0.75
# gregory-bourillon            0.25
# claudio-pizarro              0.25
# luciano-monzon               0.25
# emiliano-armenteros          0.50
# robert-huth                  0.00
# soldado                      0.00
# zubikarai                    0.00
# marc-valiente                0.25
# alvaro-rubio                 0.25
# gonzalo-jara                 0.25
# benjamin-stambouli           0.00
# jerome-boateng               0.75
# bruno-gama                   0.25
# sergi-roberto                0.25
# vincent-aboubakar            1.00
# stelios-malezas              0.25
# riesgo                       0.00
# robbie-kruse                 0.00
# nicky-shorey                 0.00
# arouna-kone                  1.00
# stilian-petrov               0.25
# gael-danic                   0.00
# nelson_4                     0.50
# holger-badstuber             0.00
# fabrice-abriel               0.50
# marcel-schaefer              0.25
# hajime-hosogai               0.25
# brad-guzan                   0.00
# victor-ruiz_2                0.25
# Name: skinColor, dtype: float64

# %%
def genLabels(s):
    return np.asarray(s, dtype="|S6")

rf = ensemble.RandomForestClassifier(max_depth = 10, min_samples_split = 5, random_state = 42)
rf.fit(X_train, genLabels(y_train))
res = rf.predict(X_test) == genLabels(y_test)
len(list(filter(lambda x: x, res)))/len(res)
# Out:
# 0.4478114478114478

# %%
list(df['birthday'][[1]])[0]
# Out:
# Timestamp('1982-08-01 00:00:00')
